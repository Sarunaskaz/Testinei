# %%
from selenium import webdriver
import os
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import requests

options = Options()
options.add_argument('--incognito')

driver = webdriver.Chrome(options=options)

url = 'https://m.autoplius.lt/skelbimai/naudoti-automobiliai'

driver.get(url)

photos = driver.find_elements(By.CLASS_NAME, 'js-gallery-photo')

for i, photo in enumerate(photos):
    print(i, photo.get_attribute('src'))
# Out:
# 0 https://autoplius-img.dgn.lt/ann_25_315061094/audi-a1-1-4-l-hecbekas-2010-benzinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315061096/audi-a1-1-4-l-hecbekas-2010-benzinas.jpg
# 2 https://autoplius-img.dgn.lt/ann_25_315061100/audi-a1-1-4-l-hecbekas-2010-benzinas.jpg
# 3 https://autoplius-img.dgn.lt/ann_25_315061102/audi-a1-1-4-l-hecbekas-2010-benzinas.jpg
# 4 https://autoplius-img.dgn.lt/ann_25_311311410/bmw-535-gran-turismo-3-0-l-hecbekas-2014-benzinas.jpg
# 5 https://autoplius-img.dgn.lt/ann_25_311311416/bmw-535-gran-turismo-3-0-l-hecbekas-2014-benzinas.jpg
# 6 https://autoplius-img.dgn.lt/ann_25_311311426/bmw-535-gran-turismo-3-0-l-hecbekas-2014-benzinas.jpg
# 7 https://autoplius-img.dgn.lt/ann_25_311311434/bmw-535-gran-turismo-3-0-l-hecbekas-2014-benzinas.jpg
# 8 https://autoplius-img.dgn.lt/ann_25_314057104/bmw-320-2-0-l-sedanas-2019-dyzelinas.jpg
# 9 https://autoplius-img.dgn.lt/ann_25_314056832/bmw-320-2-0-l-sedanas-2019-dyzelinas.jpg
# 10 https://autoplius-img.dgn.lt/ann_25_314056834/bmw-320-2-0-l-sedanas-2019-dyzelinas.jpg
# 11 https://autoplius-img.dgn.lt/ann_25_314056836/bmw-320-2-0-l-sedanas-2019-dyzelinas.jpg
# 12 https://autoplius-img.dgn.lt/ann_25_315409492/volkswagen-multivan-keleivinis-mikroautobusas-2021-dyzelinas.jpg
# 13 https://autoplius-img.dgn.lt/ann_25_315409484/volkswagen-multivan-keleivinis-mikroautobusas-2021-dyzelinas.jpg
# 14 https://autoplius-img.dgn.lt/ann_25_315409480/volkswagen-multivan-keleivinis-mikroautobusas-2021-dyzelinas.jpg
# 15 https://autoplius-img.dgn.lt/ann_25_315409500/volkswagen-multivan-keleivinis-mikroautobusas-2021-dyzelinas.jpg
# 16 https://autoplius-img.dgn.lt/ann_25_315428398/porsche-cayenne-3-0-l-visureigis-krosoveris-2012-dyzelinas.jpg
# 17 https://autoplius-img.dgn.lt/ann_25_315428400/porsche-cayenne-3-0-l-visureigis-krosoveris-2012-dyzelinas.jpg
# 18 https://autoplius-img.dgn.lt/ann_25_315428394/porsche-cayenne-3-0-l-visureigis-krosoveris-2012-dyzelinas.jpg
# 19 https://autoplius-img.dgn.lt/ann_25_315428320/porsche-cayenne-3-0-l-visureigis-krosoveris-2012-dyzelinas.jpg
# 20 https://autoplius-img.dgn.lt/ann_25_315250078/nissan-x-trail-2-2-l-visureigis-krosoveris-2003-dyzelinas.jpg
# 66 https://autoplius-img.dgn.lt/ann_25_315103056/audi-q8-3-0-l-visureigis-krosoveris-2019-dyzelinas-elektra.jpg
# 67 https://autoplius-img.dgn.lt/ann_25_315103058/audi-q8-3-0-l-visureigis-krosoveris-2019-dyzelinas-elektra.jpg
# 68 https://autoplius-img.dgn.lt/ann_25_315373314/volkswagen-passat-1-8-l-universalas-2002-benzinas-dujos.jpg
# 69 https://autoplius-img.dgn.lt/ann_25_315373312/volkswagen-passat-1-8-l-universalas-2002-benzinas-dujos.jpg
# 70 https://autoplius-img.dgn.lt/ann_25_315373316/volkswagen-passat-1-8-l-universalas-2002-benzinas-dujos.jpg
# 71 https://autoplius-img.dgn.lt/ann_25_315373318/volkswagen-passat-1-8-l-universalas-2002-benzinas-dujos.jpg

# %%
photos_dir= 'automobiliai'
if not os.path.exists(photos_dir):
    os.makedirs(photos_dir)
    
for i, photo in enumerate(photos):
    photo_url = photo.get_attribute('src')
    img_data = requests.get(photo_url).content
    img_name = f'{i}.jpg'
    img_path = os.path.join(photos_dir, img_name)
    with open(img_path, 'wb') as h:
        h.write(img_data)
    print(f'Isaugota nuotrauka {i} nuotrauka')
    

driver.quit()
# Out:
# Isaugota nuotrauka 0 nuotrauka
# Isaugota nuotrauka 1 nuotrauka
# Isaugota nuotrauka 2 nuotrauka
# Isaugota nuotrauka 3 nuotrauka
# Isaugota nuotrauka 4 nuotrauka
# Isaugota nuotrauka 5 nuotrauka
# Isaugota nuotrauka 6 nuotrauka
# Isaugota nuotrauka 7 nuotrauka
# Isaugota nuotrauka 8 nuotrauka
# Isaugota nuotrauka 9 nuotrauka
# Isaugota nuotrauka 10 nuotrauka
# Isaugota nuotrauka 11 nuotrauka
# Isaugota nuotrauka 12 nuotrauka
# Isaugota nuotrauka 13 nuotrauka
# Isaugota nuotrauka 14 nuotrauka
# Isaugota nuotrauka 15 nuotrauka
# Isaugota nuotrauka 16 nuotrauka
# Isaugota nuotrauka 17 nuotrauka
# Isaugota nuotrauka 18 nuotrauka
# Isaugota nuotrauka 19 nuotrauka
# Isaugota nuotrauka 20 nuotrauka
# Isaugota nuotrauka 21 nuotrauka
# Isaugota nuotrauka 22 nuotrauka
# Isaugota nuotrauka 23 nuotrauka
# Isaugota nuotrauka 24 nuotrauka
# Isaugota nuotrauka 25 nuotrauka
# Isaugota nuotrauka 26 nuotrauka
# Isaugota nuotrauka 27 nuotrauka
# Isaugota nuotrauka 28 nuotrauka
# Isaugota nuotrauka 29 nuotrauka
# Isaugota nuotrauka 30 nuotrauka
# Isaugota nuotrauka 31 nuotrauka
# Isaugota nuotrauka 32 nuotrauka
# Isaugota nuotrauka 33 nuotrauka
# Isaugota nuotrauka 34 nuotrauka
# Isaugota nuotrauka 35 nuotrauka
# Isaugota nuotrauka 36 nuotrauka
# Isaugota nuotrauka 37 nuotrauka
# Isaugota nuotrauka 38 nuotrauka
# Isaugota nuotrauka 39 nuotrauka
# Isaugota nuotrauka 40 nuotrauka
# Isaugota nuotrauka 41 nuotrauka
# Isaugota nuotrauka 42 nuotrauka
# Isaugota nuotrauka 43 nuotrauka
# Isaugota nuotrauka 44 nuotrauka
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 7
#       5 for i, photo in enumerate(photos):
#       6     photo_url = photo.get_attribute('src')
# ----> 7     img_data = requests.get(photo_url).content
#       8     img_name = f'{i}.jpg'
#       9     img_path = os.path.join(photos_dir, img_name)
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1097 # Force connect early to allow us to validate the connection.
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1102 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\urllib3\connection.py:653, in HTTPSConnection.connect(self)
#     650 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#     673 # Forwarding proxies can never have a verified target since
#     674 # the proxy is the one doing the verification. Should instead
#     675 # use a CONNECT tunnel in order to verify the target.
#     676 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\urllib3\connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     803     if is_ipaddress(normalized):
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#     820     if assert_fingerprint:
#
# File c:\Users\sarun\OneDrive\Documents\Code\Testinei\mokymai\Lib\site-packages\urllib3\util\ssl_.py:440, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     438 if ca_certs or ca_cert_dir or ca_cert_data:
#     439     try:
# --> 440         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     441     except OSError as e:
#     442         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
import time
from random import randint
options = Options()
options.add_argument('--incognito')

driver = webdriver.Chrome(options=options)

for page_nr in range(2,100):

    url = f'https://m.autoplius.lt/skelbimai/naudoti-automobiliai?page_nr={page_nr}'

    driver.get(url)

    photos = driver.find_elements(By.CLASS_NAME, 'js-gallery-photo')

    for i, photo in enumerate(photos):
        print(i, photo.get_attribute('src'))

    photos_dir = 'automobiliai'
    if not os.path.exists(photos_dir):
        os.makedirs(photos_dir)

    for i, photo in enumerate(photos):
        photo_url = photo.get_attribute('src')
        img_data = requests.get(photo_url).content
        img_name = f'{page_nr}_{i}.jpg'
        img_path = os.path.join(photos_dir, img_name)
        with open(img_path, 'wb') as h:
            h.write(img_data)
        print(f'Issaugota {i} nuotrauka')

    time.sleep(randint(1,5))


driver.quit()
# Out:
# 0 https://autoplius-img.dgn.lt/ann_25_315292856/volkswagen-passat-2-0-l-universalas-2009-dyzelinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315292858/volkswagen-passat-2-0-l-universalas-2009-dyzelinas.jpg
# 2 https://autoplius-img.dgn.lt/ann_25_315292882/volkswagen-passat-2-0-l-universalas-2009-dyzelinas.jpg
# 3 https://autoplius-img.dgn.lt/ann_25_315500350/volkswagen-passat-2-0-l-universalas-2007-dyzelinas.jpg
# 4 https://autoplius-img.dgn.lt/ann_25_315500356/volkswagen-passat-2-0-l-universalas-2007-dyzelinas.jpg
# 5 https://autoplius-img.dgn.lt/ann_25_315500358/volkswagen-passat-2-0-l-universalas-2007-dyzelinas.jpg
# 6 https://autoplius-img.dgn.lt/ann_25_315500352/volkswagen-passat-2-0-l-universalas-2007-dyzelinas.jpg
# 7 https://autoplius-img.dgn.lt/ann_25_315208732/volkswagen-passat-2-0-l-universalas-2006-dyzelinas.jpg
# 8 https://autoplius-img.dgn.lt/ann_25_315208750/volkswagen-passat-2-0-l-universalas-2006-dyzelinas.jpg
# 9 https://autoplius-img.dgn.lt/ann_25_315208738/volkswagen-passat-2-0-l-universalas-2006-dyzelinas.jpg
# 10 https://autoplius-img.dgn.lt/ann_25_315208744/volkswagen-passat-2-0-l-universalas-2006-dyzelinas.jpg
# 11 https://autoplius-img.dgn.lt/ann_25_314158952/bmw-530-3-0-l-sedanas-2004-dyzelinas.jpg
# 12 https://autoplius-img.dgn.lt/ann_25_314158964/bmw-530-3-0-l-sedanas-2004-dyzelinas.jpg
# 13 https://autoplius-img.dgn.lt/ann_25_314158958/bmw-530-3-0-l-sedanas-2004-dyzelinas.jpg
# 41 https://autoplius-img.dgn.lt/ann_25_309077101/volkswagen-tiguan-2-0-l-visureigis-krosoveris-2020-dyzelinas.jpg
# 42 https://autoplius-img.dgn.lt/ann_25_309077103/volkswagen-tiguan-2-0-l-visureigis-krosoveris-2020-dyzelinas.jpg
# 43 https://autoplius-img.dgn.lt/ann_25_309077105/volkswagen-tiguan-2-0-l-visureigis-krosoveris-2020-dyzelinas.jpg
# 44 https://autoplius-img.dgn.lt/ann_25_315171270/volkswagen-passat-2-0-l-sedanas-2019-benzinas.jpg
# 45 https://autoplius-img.dgn.lt/ann_25_315171272/volkswagen-passat-2-0-l-sedanas-2019-benzinas.jpg
# 46 https://autoplius-img.dgn.lt/ann_25_315171274/volkswagen-passat-2-0-l-sedanas-2019-benzinas.jpg
# 47 https://autoplius-img.dgn.lt/ann_25_315171276/volkswagen-passat-2-0-l-sedanas-2019-benzinas.jpg
# 48 https://autoplius-img.dgn.lt/ann_25_309077425/volkswagen-tiguan-1-5-l-visureigis-krosoveris-2021-benzinas.jpg
# 49 https://autoplius-img.dgn.lt/ann_25_309077427/volkswagen-tiguan-1-5-l-visureigis-krosoveris-2021-benzinas.jpg
# 50 https://autoplius-img.dgn.lt/ann_25_309077431/volkswagen-tiguan-1-5-l-visureigis-krosoveris-2021-benzinas.jpg
# 51 https://autoplius-img.dgn.lt/ann_25_309077433/volkswagen-tiguan-1-5-l-visureigis-krosoveris-2021-benzinas.jpg
# 52 https://autoplius-img.dgn.lt/ann_25_312984434/volkswagen-tiguan-2-0-l-visureigis-krosoveris-2018-dyzelinas.jpg
# 53 https://autoplius-img.dgn.lt/ann_25_312984436/volkswagen-tiguan-2-0-l-visureigis-krosoveris-2018-dyzelinas.jpg
# 54 https://autoplius-img.dgn.lt/ann_25_312984438/volkswagen-tiguan-2-0-l-visureigis-krosoveris-2018-dyzelinas.jpg
# 55 https://autoplius-img.dgn.lt/ann_25_312984440/volkswagen-tiguan-2-0-l-visureigis-krosoveris-2018-dyzelinas.jpg
# Issaugota 0 nuotrauka
# Issaugota 1 nuotrauka
# Issaugota 2 nuotrauka
# Issaugota 3 nuotrauka
# Issaugota 4 nuotrauka
# Issaugota 5 nuotrauka
# Issaugota 6 nuotrauka
# Issaugota 7 nuotrauka
# Issaugota 8 nuotrauka
# Issaugota 9 nuotrauka
# Issaugota 10 nuotrauka
# Issaugota 11 nuotrauka
# Issaugota 12 nuotrauka
# Issaugota 13 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 33 nuotrauka
# Issaugota 34 nuotrauka
# Issaugota 35 nuotrauka
# Issaugota 36 nuotrauka
# Issaugota 37 nuotrauka
# Issaugota 38 nuotrauka
# Issaugota 39 nuotrauka
# Issaugota 40 nuotrauka
# Issaugota 41 nuotrauka
# Issaugota 42 nuotrauka
# Issaugota 43 nuotrauka
# Issaugota 44 nuotrauka
# Issaugota 45 nuotrauka
# Issaugota 46 nuotrauka
# Issaugota 47 nuotrauka
# Issaugota 48 nuotrauka
# Issaugota 49 nuotrauka
# Issaugota 50 nuotrauka
# Issaugota 51 nuotrauka
# Issaugota 52 nuotrauka
# Issaugota 53 nuotrauka
# Issaugota 54 nuotrauka
# Issaugota 55 nuotrauka
# Issaugota 56 nuotrauka
# Issaugota 57 nuotrauka
# Issaugota 58 nuotrauka
# 0 https://autoplius-img.dgn.lt/ann_25_315496956/toyota-avensis-2-0-l-universalas-2005-dyzelinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315496960/toyota-avensis-2-0-l-universalas-2005-dyzelinas.jpg
# 2 https://autoplius-img.dgn.lt/ann_25_315496974/toyota-avensis-2-0-l-universalas-2005-dyzelinas.jpg
# 3 https://autoplius-img.dgn.lt/ann_25_315497000/toyota-avensis-2-0-l-universalas-2005-dyzelinas.jpg
# 4 https://autoplius-img.dgn.lt/ann_25_315498430/seat-alhambra-1-9-l-vienaturis-2003-dyzelinas.jpg
# 5 https://autoplius-img.dgn.lt/ann_25_315498436/seat-alhambra-1-9-l-vienaturis-2003-dyzelinas.jpg
# 6 https://autoplius-img.dgn.lt/ann_25_315498438/seat-alhambra-1-9-l-vienaturis-2003-dyzelinas.jpg
# 7 https://autoplius-img.dgn.lt/ann_25_315498442/seat-alhambra-1-9-l-vienaturis-2003-dyzelinas.jpg
# 8 https://autoplius-img.dgn.lt/ann_25_315499510/volkswagen-golf-1-9-l-hecbekas-2007-dyzelinas.jpg
# 9 https://autoplius-img.dgn.lt/ann_25_315499514/volkswagen-golf-1-9-l-hecbekas-2007-dyzelinas.jpg
# 10 https://autoplius-img.dgn.lt/ann_25_315499516/volkswagen-golf-1-9-l-hecbekas-2007-dyzelinas.jpg
# 11 https://autoplius-img.dgn.lt/ann_25_315477518/volvo-v50-2-0-l-universalas-2006-dyzelinas.jpg
# 12 https://autoplius-img.dgn.lt/ann_25_315477520/volvo-v50-2-0-l-universalas-2006-dyzelinas.jpg
# 61 https://autoplius-img.dgn.lt/ann_25_315423160/bmw-320-2-0-l-universalas-2008-dyzelinas.jpg
# 62 https://autoplius-img.dgn.lt/ann_25_315421344/volvo-xc90-2-4-l-visureigis-krosoveris-2005-dyzelinas.jpg
# 63 https://autoplius-img.dgn.lt/ann_25_315421346/volvo-xc90-2-4-l-visureigis-krosoveris-2005-dyzelinas.jpg
# 64 https://autoplius-img.dgn.lt/ann_25_315421348/volvo-xc90-2-4-l-visureigis-krosoveris-2005-dyzelinas.jpg
# 65 https://autoplius-img.dgn.lt/ann_25_315421350/volvo-xc90-2-4-l-visureigis-krosoveris-2005-dyzelinas.jpg
# 66 https://autoplius-img.dgn.lt/ann_25_315496258/chevrolet-captiva-2-0-l-visureigis-krosoveris-2008-dyzelinas.jpg
# 67 https://autoplius-img.dgn.lt/ann_25_315496266/chevrolet-captiva-2-0-l-visureigis-krosoveris-2008-dyzelinas.jpg
# 68 https://autoplius-img.dgn.lt/ann_25_315496270/chevrolet-captiva-2-0-l-visureigis-krosoveris-2008-dyzelinas.jpg
# 69 https://autoplius-img.dgn.lt/ann_25_315496262/chevrolet-captiva-2-0-l-visureigis-krosoveris-2008-dyzelinas.jpg
# 70 https://autoplius-img.dgn.lt/ann_25_315497350/nissan-x-trail-2-2-l-visureigis-krosoveris-2006-dyzelinas.jpg
# 71 https://autoplius-img.dgn.lt/ann_25_315497364/nissan-x-trail-2-2-l-visureigis-krosoveris-2006-dyzelinas.jpg
# 72 https://autoplius-img.dgn.lt/ann_25_315497372/nissan-x-trail-2-2-l-visureigis-krosoveris-2006-dyzelinas.jpg
# 73 https://autoplius-img.dgn.lt/ann_25_315497380/nissan-x-trail-2-2-l-visureigis-krosoveris-2006-dyzelinas.jpg
# Issaugota 0 nuotrauka
# Issaugota 1 nuotrauka
# Issaugota 2 nuotrauka
# Issaugota 3 nuotrauka
# Issaugota 4 nuotrauka
# Issaugota 5 nuotrauka
# Issaugota 6 nuotrauka
# Issaugota 7 nuotrauka
# Issaugota 8 nuotrauka
# Issaugota 9 nuotrauka
# Issaugota 10 nuotrauka
# Issaugota 11 nuotrauka
# Issaugota 12 nuotrauka
# Issaugota 13 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 33 nuotrauka
# Issaugota 34 nuotrauka
# Issaugota 35 nuotrauka
# Issaugota 36 nuotrauka
# Issaugota 37 nuotrauka
# Issaugota 38 nuotrauka
# Issaugota 39 nuotrauka
# Issaugota 40 nuotrauka
# Issaugota 41 nuotrauka
# Issaugota 42 nuotrauka
# Issaugota 43 nuotrauka
# Issaugota 44 nuotrauka
# Issaugota 45 nuotrauka
# Issaugota 46 nuotrauka
# Issaugota 47 nuotrauka
# Issaugota 48 nuotrauka
# Issaugota 49 nuotrauka
# Issaugota 50 nuotrauka
# Issaugota 51 nuotrauka
# Issaugota 52 nuotrauka
# Issaugota 53 nuotrauka
# Issaugota 54 nuotrauka
# Issaugota 55 nuotrauka
# Issaugota 56 nuotrauka
# Issaugota 57 nuotrauka
# Issaugota 58 nuotrauka
# Issaugota 59 nuotrauka
# Issaugota 60 nuotrauka
# Issaugota 61 nuotrauka
# Issaugota 62 nuotrauka
# Issaugota 63 nuotrauka
# Issaugota 64 nuotrauka
# Issaugota 65 nuotrauka
# Issaugota 66 nuotrauka
# Issaugota 67 nuotrauka
# Issaugota 68 nuotrauka
# Issaugota 69 nuotrauka
# Issaugota 70 nuotrauka
# Issaugota 71 nuotrauka
# Issaugota 72 nuotrauka
# Issaugota 73 nuotrauka
# 0 https://autoplius-img.dgn.lt/ann_25_315244974/bmw-x5-2-9-l-visureigis-krosoveris-2002-dyzelinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315244980/bmw-x5-2-9-l-visureigis-krosoveris-2002-dyzelinas.jpg
# 2 https://autoplius-img.dgn.lt/ann_25_315244984/bmw-x5-2-9-l-visureigis-krosoveris-2002-dyzelinas.jpg
# 3 https://autoplius-img.dgn.lt/ann_25_315244990/bmw-x5-2-9-l-visureigis-krosoveris-2002-dyzelinas.jpg
# 4 https://autoplius-img.dgn.lt/ann_25_315116798/audi-a6-3-0-l-universalas-2006-dyzelinas.jpg
# 5 https://autoplius-img.dgn.lt/ann_25_315116802/audi-a6-3-0-l-universalas-2006-dyzelinas.jpg
# 6 https://autoplius-img.dgn.lt/ann_25_315116804/audi-a6-3-0-l-universalas-2006-dyzelinas.jpg
# 7 https://autoplius-img.dgn.lt/ann_25_315116806/audi-a6-3-0-l-universalas-2006-dyzelinas.jpg
# 8 https://autoplius-img.dgn.lt/ann_25_315493688/audi-a3-2-0-l-hecbekas-2007-dyzelinas.jpg
# 9 https://autoplius-img.dgn.lt/ann_25_315493694/audi-a3-2-0-l-hecbekas-2007-dyzelinas.jpg
# 10 https://autoplius-img.dgn.lt/ann_25_315493698/audi-a3-2-0-l-hecbekas-2007-dyzelinas.jpg
# 11 https://autoplius-img.dgn.lt/ann_25_315493690/audi-a3-2-0-l-hecbekas-2007-dyzelinas.jpg
# 12 https://autoplius-img.dgn.lt/ann_25_315499212/toyota-corolla-1-6-l-sedanas-2008-benzinas-dujos.jpg
# 13 https://autoplius-img.dgn.lt/ann_25_315499224/toyota-corolla-1-6-l-sedanas-2008-benzinas-dujos.jpg
# 14 https://autoplius-img.dgn.lt/ann_25_315499216/toyota-corolla-1-6-l-sedanas-2008-benzinas-dujos.jpg
# 15 https://autoplius-img.dgn.lt/ann_25_315499240/toyota-corolla-1-6-l-sedanas-2008-benzinas-dujos.jpg
# 63 https://autoplius-img.dgn.lt/ann_25_315496962/kia-sorento-2-5-l-visureigis-krosoveris-2008-dyzelinas.jpg
# 64 https://autoplius-img.dgn.lt/ann_25_315498090/renault-trafic-2-0-l-vienaturis-2008-dyzelinas.jpg
# 65 https://autoplius-img.dgn.lt/ann_25_315498092/renault-trafic-2-0-l-vienaturis-2008-dyzelinas.jpg
# 66 https://autoplius-img.dgn.lt/ann_25_315498094/renault-trafic-2-0-l-vienaturis-2008-dyzelinas.jpg
# 67 https://autoplius-img.dgn.lt/ann_25_315498098/renault-trafic-2-0-l-vienaturis-2008-dyzelinas.jpg
# Issaugota 0 nuotrauka
# Issaugota 1 nuotrauka
# Issaugota 2 nuotrauka
# Issaugota 3 nuotrauka
# Issaugota 4 nuotrauka
# Issaugota 5 nuotrauka
# Issaugota 6 nuotrauka
# Issaugota 7 nuotrauka
# Issaugota 8 nuotrauka
# Issaugota 9 nuotrauka
# Issaugota 10 nuotrauka
# Issaugota 11 nuotrauka
# Issaugota 12 nuotrauka
# Issaugota 13 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 33 nuotrauka
# Issaugota 34 nuotrauka
# Issaugota 35 nuotrauka
# Issaugota 36 nuotrauka
# Issaugota 37 nuotrauka
# Issaugota 38 nuotrauka
# Issaugota 39 nuotrauka
# Issaugota 40 nuotrauka
# Issaugota 41 nuotrauka
# Issaugota 42 nuotrauka
# Issaugota 43 nuotrauka
# Issaugota 44 nuotrauka
# Issaugota 45 nuotrauka
# Issaugota 46 nuotrauka
# Issaugota 47 nuotrauka
# Issaugota 48 nuotrauka
# Issaugota 49 nuotrauka
# Issaugota 50 nuotrauka
# Issaugota 51 nuotrauka
# Issaugota 52 nuotrauka
# Issaugota 53 nuotrauka
# Issaugota 54 nuotrauka
# Issaugota 55 nuotrauka
# Issaugota 56 nuotrauka
# Issaugota 57 nuotrauka
# Issaugota 58 nuotrauka
# Issaugota 59 nuotrauka
# Issaugota 60 nuotrauka
# Issaugota 61 nuotrauka
# Issaugota 62 nuotrauka
# Issaugota 63 nuotrauka
# Issaugota 64 nuotrauka
# Issaugota 65 nuotrauka
# Issaugota 66 nuotrauka
# Issaugota 67 nuotrauka
# 0 https://autoplius-img.dgn.lt/ann_25_315439328/alfa-romeo-159-2-4-l-universalas-2008-dyzelinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315439332/alfa-romeo-159-2-4-l-universalas-2008-dyzelinas.jpg
# 26 https://autoplius-img.dgn.lt/ann_25_309839503/mercedes-benz-c220-2-1-l-sedanas-2012-dyzelinas.jpg
# 27 https://autoplius-img.dgn.lt/ann_25_309839611/mercedes-benz-c220-2-1-l-sedanas-2012-dyzelinas.jpg
# 28 https://autoplius-img.dgn.lt/ann_25_315452210/bmw-x5-3-0-l-visureigis-krosoveris-2007-dyzelinas.jpg
# 29 https://autoplius-img.dgn.lt/ann_25_315452212/bmw-x5-3-0-l-visureigis-krosoveris-2007-dyzelinas.jpg
# 30 https://autoplius-img.dgn.lt/ann_25_315452220/bmw-x5-3-0-l-visureigis-krosoveris-2007-dyzelinas.jpg
# 31 https://autoplius-img.dgn.lt/ann_25_315452214/bmw-x5-3-0-l-visureigis-krosoveris-2007-dyzelinas.jpg
# 32 https://autoplius-img.dgn.lt/ann_25_313594678/mercedes-benz-sprinter-2-2-l-keleivinis-mikroautobusas-2014-dyzelinas.jpg
# 33 https://autoplius-img.dgn.lt/ann_25_313594634/mercedes-benz-sprinter-2-2-l-keleivinis-mikroautobusas-2014-dyzelinas.jpg
# 34 https://autoplius-img.dgn.lt/ann_25_313594600/mercedes-benz-sprinter-2-2-l-keleivinis-mikroautobusas-2014-dyzelinas.jpg
# 35 https://autoplius-img.dgn.lt/ann_25_313594654/mercedes-benz-sprinter-2-2-l-keleivinis-mikroautobusas-2014-dyzelinas.jpg
# Issaugota 0 nuotrauka
# Issaugota 1 nuotrauka
# Issaugota 2 nuotrauka
# Issaugota 3 nuotrauka
# Issaugota 4 nuotrauka
# Issaugota 5 nuotrauka
# Issaugota 6 nuotrauka
# Issaugota 7 nuotrauka
# Issaugota 8 nuotrauka
# Issaugota 9 nuotrauka
# Issaugota 10 nuotrauka
# Issaugota 11 nuotrauka
# Issaugota 12 nuotrauka
# Issaugota 13 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 33 nuotrauka
# Issaugota 34 nuotrauka
# Issaugota 35 nuotrauka
# 0 https://autoplius-img.dgn.lt/ann_25_315077244/bmw-730-3-0-l-sedanas-2010-dyzelinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315077272/bmw-730-3-0-l-sedanas-2010-dyzelinas.jpg
# 2 https://autoplius-img.dgn.lt/ann_25_315077236/bmw-730-3-0-l-sedanas-2010-dyzelinas.jpg
# 3 https://autoplius-img.dgn.lt/ann_25_315077254/bmw-730-3-0-l-sedanas-2010-dyzelinas.jpg
# 28 https://autoplius-img.dgn.lt/ann_25_315418776/jaguar-xf-3-0-l-sedanas-2010-dyzelinas.jpg
# 29 https://autoplius-img.dgn.lt/ann_25_315418832/jaguar-xf-3-0-l-sedanas-2010-dyzelinas.jpg
# 30 https://autoplius-img.dgn.lt/ann_25_315418886/jaguar-xf-3-0-l-sedanas-2010-dyzelinas.jpg
# 31 https://autoplius-img.dgn.lt/ann_25_315418932/jaguar-xf-3-0-l-sedanas-2010-dyzelinas.jpg
# 32 https://autoplius-img.dgn.lt/ann_25_313351670/lexus-gs-300h-2-5-l-sedanas-2013-benzinas-elektra.jpg
# 33 https://autoplius-img.dgn.lt/ann_25_313351598/lexus-gs-300h-2-5-l-sedanas-2013-benzinas-elektra.jpg
# 34 https://autoplius-img.dgn.lt/ann_25_313351606/lexus-gs-300h-2-5-l-sedanas-2013-benzinas-elektra.jpg
# 35 https://autoplius-img.dgn.lt/ann_25_313351614/lexus-gs-300h-2-5-l-sedanas-2013-benzinas-elektra.jpg
# 36 https://autoplius-img.dgn.lt/ann_25_315241690/skoda-superb-2-0-l-universalas-2017-dyzelinas.jpg
# 37 https://autoplius-img.dgn.lt/ann_25_315241694/skoda-superb-2-0-l-universalas-2017-dyzelinas.jpg
# 38 https://autoplius-img.dgn.lt/ann_25_315241686/skoda-superb-2-0-l-universalas-2017-dyzelinas.jpg
# 39 https://autoplius-img.dgn.lt/ann_25_315241672/skoda-superb-2-0-l-universalas-2017-dyzelinas.jpg
# Issaugota 0 nuotrauka
# Issaugota 1 nuotrauka
# Issaugota 2 nuotrauka
# Issaugota 3 nuotrauka
# Issaugota 4 nuotrauka
# Issaugota 5 nuotrauka
# Issaugota 6 nuotrauka
# Issaugota 7 nuotrauka
# Issaugota 8 nuotrauka
# Issaugota 9 nuotrauka
# Issaugota 10 nuotrauka
# Issaugota 11 nuotrauka
# Issaugota 12 nuotrauka
# Issaugota 13 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 33 nuotrauka
# Issaugota 34 nuotrauka
# Issaugota 35 nuotrauka
# Issaugota 36 nuotrauka
# Issaugota 37 nuotrauka
# Issaugota 38 nuotrauka
# Issaugota 39 nuotrauka
# 0 https://autoplius-img.dgn.lt/ann_25_315272016/audi-a6-3-0-l-universalas-2012-dyzelinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315272028/audi-a6-3-0-l-universalas-2012-dyzelinas.jpg
# 55 https://autoplius-img.dgn.lt/ann_25_313334470/opel-astra-1-7-l-universalas-2014-dyzelinas.jpg
# 56 https://autoplius-img.dgn.lt/ann_25_311564290/ford-c-max-1-0-l-vienaturis-2013-benzinas.jpg
# 57 https://autoplius-img.dgn.lt/ann_25_311564296/ford-c-max-1-0-l-vienaturis-2013-benzinas.jpg
# 58 https://autoplius-img.dgn.lt/ann_25_311564306/ford-c-max-1-0-l-vienaturis-2013-benzinas.jpg
# 59 https://autoplius-img.dgn.lt/ann_25_311564316/ford-c-max-1-0-l-vienaturis-2013-benzinas.jpg
# 60 https://autoplius-img.dgn.lt/ann_25_312068890/bmw-320-2-0-l-universalas-2010-dyzelinas.jpg
# 61 https://autoplius-img.dgn.lt/ann_25_312068900/bmw-320-2-0-l-universalas-2010-dyzelinas.jpg
# 62 https://autoplius-img.dgn.lt/ann_25_312068912/bmw-320-2-0-l-universalas-2010-dyzelinas.jpg
# 63 https://autoplius-img.dgn.lt/ann_25_312068928/bmw-320-2-0-l-universalas-2010-dyzelinas.jpg
# 64 https://autoplius-img.dgn.lt/ann_25_311056159/chrysler-grand-voyager-2-8-l-vienaturis-2008-dyzelinas.jpg
# 65 https://autoplius-img.dgn.lt/ann_25_311056139/chrysler-grand-voyager-2-8-l-vienaturis-2008-dyzelinas.jpg
# 66 https://autoplius-img.dgn.lt/ann_25_311056151/chrysler-grand-voyager-2-8-l-vienaturis-2008-dyzelinas.jpg
# 67 https://autoplius-img.dgn.lt/ann_25_311056161/chrysler-grand-voyager-2-8-l-vienaturis-2008-dyzelinas.jpg
# 68 https://autoplius-img.dgn.lt/ann_25_313407496/peugeot-5008-1-6-l-vienaturis-2013-dyzelinas.jpg
# 69 https://autoplius-img.dgn.lt/ann_25_313407504/peugeot-5008-1-6-l-vienaturis-2013-dyzelinas.jpg
# 70 https://autoplius-img.dgn.lt/ann_25_313407518/peugeot-5008-1-6-l-vienaturis-2013-dyzelinas.jpg
# 71 https://autoplius-img.dgn.lt/ann_25_313407524/peugeot-5008-1-6-l-vienaturis-2013-dyzelinas.jpg
# 72 https://autoplius-img.dgn.lt/ann_25_315335900/skoda-octavia-1-6-l-universalas-2013-dyzelinas.jpg
# 73 https://autoplius-img.dgn.lt/ann_25_315335904/skoda-octavia-1-6-l-universalas-2013-dyzelinas.jpg
# 74 https://autoplius-img.dgn.lt/ann_25_315335906/skoda-octavia-1-6-l-universalas-2013-dyzelinas.jpg
# 75 https://autoplius-img.dgn.lt/ann_25_315335912/skoda-octavia-1-6-l-universalas-2013-dyzelinas.jpg
# Issaugota 0 nuotrauka
# Issaugota 1 nuotrauka
# Issaugota 2 nuotrauka
# Issaugota 3 nuotrauka
# Issaugota 4 nuotrauka
# Issaugota 5 nuotrauka
# Issaugota 6 nuotrauka
# Issaugota 7 nuotrauka
# Issaugota 8 nuotrauka
# Issaugota 9 nuotrauka
# Issaugota 10 nuotrauka
# Issaugota 11 nuotrauka
# Issaugota 12 nuotrauka
# Issaugota 13 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 33 nuotrauka
# Issaugota 34 nuotrauka
# Issaugota 35 nuotrauka
# Issaugota 36 nuotrauka
# Issaugota 37 nuotrauka
# Issaugota 38 nuotrauka
# Issaugota 39 nuotrauka
# Issaugota 40 nuotrauka
# Issaugota 41 nuotrauka
# Issaugota 42 nuotrauka
# Issaugota 43 nuotrauka
# Issaugota 44 nuotrauka
# Issaugota 45 nuotrauka
# Issaugota 46 nuotrauka
# Issaugota 47 nuotrauka
# Issaugota 48 nuotrauka
# Issaugota 49 nuotrauka
# Issaugota 50 nuotrauka
# Issaugota 51 nuotrauka
# Issaugota 52 nuotrauka
# Issaugota 53 nuotrauka
# Issaugota 54 nuotrauka
# Issaugota 55 nuotrauka
# Issaugota 56 nuotrauka
# Issaugota 57 nuotrauka
# Issaugota 58 nuotrauka
# Issaugota 59 nuotrauka
# Issaugota 60 nuotrauka
# Issaugota 61 nuotrauka
# Issaugota 62 nuotrauka
# Issaugota 63 nuotrauka
# Issaugota 64 nuotrauka
# Issaugota 65 nuotrauka
# Issaugota 66 nuotrauka
# Issaugota 67 nuotrauka
# Issaugota 68 nuotrauka
# Issaugota 69 nuotrauka
# Issaugota 70 nuotrauka
# Issaugota 71 nuotrauka
# Issaugota 72 nuotrauka
# Issaugota 73 nuotrauka
# Issaugota 74 nuotrauka
# Issaugota 75 nuotrauka
# 0 https://autoplius-img.dgn.lt/ann_25_315332912/bmw-330-3-0-l-sedanas-2007-dyzelinas.jpg
# 1 https://autoplius-img.dgn.lt/ann_25_315332916/bmw-330-3-0-l-sedanas-2007-dyzelinas.jpg
# 2 https://autoplius-img.dgn.lt/ann_25_315332918/bmw-330-3-0-l-sedanas-2007-dyzelinas.jpg
# 3 https://autoplius-img.dgn.lt/ann_25_315332966/bmw-330-3-0-l-sedanas-2007-dyzelinas.jpg
# 4 https://autoplius-img.dgn.lt/ann_25_315166804/audi-a4-2-0-l-universalas-2008-dyzelinas.jpg
# 5 https://autoplius-img.dgn.lt/ann_25_315166806/audi-a4-2-0-l-universalas-2008-dyzelinas.jpg
# 6 https://autoplius-img.dgn.lt/ann_25_315166808/audi-a4-2-0-l-universalas-2008-dyzelinas.jpg
# 7 https://autoplius-img.dgn.lt/ann_25_315166812/audi-a4-2-0-l-universalas-2008-dyzelinas.jpg
# 8 https://autoplius-img.dgn.lt/ann_25_315169712/audi-a4-2-0-l-universalas-2008-benzinas.jpg
# 57 https://autoplius-img.dgn.lt/ann_25_314209948/volkswagen-touran-2-0-l-vienaturis-2008-dyzelinas.jpg
# 58 https://autoplius-img.dgn.lt/ann_25_314209944/volkswagen-touran-2-0-l-vienaturis-2008-dyzelinas.jpg
# 59 https://autoplius-img.dgn.lt/ann_25_314209946/volkswagen-touran-2-0-l-vienaturis-2008-dyzelinas.jpg
# 60 https://autoplius-img.dgn.lt/ann_25_300237329/volvo-v70-2-0-l-universalas-2009-dyzelinas.jpg
# 61 https://autoplius-img.dgn.lt/ann_25_300237327/volvo-v70-2-0-l-universalas-2009-dyzelinas.jpg
# 62 https://autoplius-img.dgn.lt/ann_25_300237331/volvo-v70-2-0-l-universalas-2009-dyzelinas.jpg
# 63 https://autoplius-img.dgn.lt/ann_25_300237333/volvo-v70-2-0-l-universalas-2009-dyzelinas.jpg
# 64 https://autoplius-img.dgn.lt/ann_25_312057502/volkswagen-sharan-1-9-l-vienaturis-2005-dyzelinas.jpg
# 65 https://autoplius-img.dgn.lt/ann_25_312057496/volkswagen-sharan-1-9-l-vienaturis-2005-dyzelinas.jpg
# 66 https://autoplius-img.dgn.lt/ann_25_312057484/volkswagen-sharan-1-9-l-vienaturis-2005-dyzelinas.jpg
# 67 https://autoplius-img.dgn.lt/ann_25_312057476/volkswagen-sharan-1-9-l-vienaturis-2005-dyzelinas.jpg
# 68 https://autoplius-img.dgn.lt/ann_25_315417940/opel-astra-1-6-l-hecbekas-2011-benzinas.jpg
# 69 https://autoplius-img.dgn.lt/ann_25_315417996/opel-astra-1-6-l-hecbekas-2011-benzinas.jpg
# 70 https://autoplius-img.dgn.lt/ann_25_315417924/opel-astra-1-6-l-hecbekas-2011-benzinas.jpg
# 71 https://autoplius-img.dgn.lt/ann_25_315417936/opel-astra-1-6-l-hecbekas-2011-benzinas.jpg
# Issaugota 0 nuotrauka
# Issaugota 1 nuotrauka
# Issaugota 2 nuotrauka
# Issaugota 3 nuotrauka
# Issaugota 4 nuotrauka
# Issaugota 5 nuotrauka
# Issaugota 6 nuotrauka
# Issaugota 7 nuotrauka
# Issaugota 8 nuotrauka
# Issaugota 9 nuotrauka
# Issaugota 10 nuotrauka
# Issaugota 11 nuotrauka
# Issaugota 12 nuotrauka
# Issaugota 13 nuotrauka
# Issaugota 14 nuotrauka
# Issaugota 15 nuotrauka
# Issaugota 16 nuotrauka
# Issaugota 17 nuotrauka
# Issaugota 18 nuotrauka
# Issaugota 19 nuotrauka
# Issaugota 20 nuotrauka
# Issaugota 21 nuotrauka
# Issaugota 22 nuotrauka
# Issaugota 23 nuotrauka
# Issaugota 24 nuotrauka
# Issaugota 25 nuotrauka
# Issaugota 26 nuotrauka
# Issaugota 27 nuotrauka
# Issaugota 28 nuotrauka
# Issaugota 29 nuotrauka
# Issaugota 30 nuotrauka
# Issaugota 31 nuotrauka
# Issaugota 32 nuotrauka
# Issaugota 33 nuotrauka
# Issaugota 34 nuotrauka
# Issaugota 35 nuotrauka
# Issaugota 36 nuotrauka
# Issaugota 37 nuotrauka
# Issaugota 38 nuotrauka
# Issaugota 39 nuotrauka
# Issaugota 40 nuotrauka
# Issaugota 41 nuotrauka
# Issaugota 42 nuotrauka
# Issaugota 43 nuotrauka
# Issaugota 44 nuotrauka
# Issaugota 45 nuotrauka
# Issaugota 46 nuotrauka
# Issaugota 47 nuotrauka
# Issaugota 48 nuotrauka
# Issaugota 49 nuotrauka
# Issaugota 50 nuotrauka
# Issaugota 51 nuotrauka
# Issaugota 52 nuotrauka
# Issaugota 53 nuotrauka
# Issaugota 54 nuotrauka
# Issaugota 55 nuotrauka
# Issaugota 56 nuotrauka
# Issaugota 57 nuotrauka
# Issaugota 58 nuotrauka
# Issaugota 59 nuotrauka
# Issaugota 60 nuotrauka
# Issaugota 61 nuotrauka
# Issaugota 62 nuotrauka
# Issaugota 63 nuotrauka
# Issaugota 64 nuotrauka
# Issaugota 65 nuotrauka
# Issaugota 66 nuotrauka
# Issaugota 67 nuotrauka
# Issaugota 68 nuotrauka
# Issaugota 69 nuotrauka
# Issaugota 70 nuotrauka
# Issaugota 71 nuotrauka

# %%
from selenium import webdriver
import os
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import requests

options = Options()
options.add_argument('--incognito')

driver = webdriver.Chrome(options=options)
import time
from random import randint
options = Options()
options.add_argument('--incognito')

driver = webdriver.Chrome(options=options)

for page_nr in range(1,100):

    url = f'https://m.autoplius.lt/skelbimai/motociklai-moto-apranga/motociklai?qt=&page_nr={page_nr}'

    driver.get(url)

    photos = driver.find_elements(By.CLASS_NAME, 'js-gallery-photo')

    for i, photo in enumerate(photos):
        print(i, photo.get_attribute('src'))

    photos_dir = 'motociklai'
    if not os.path.exists(photos_dir):
        os.makedirs(photos_dir)
    for i, photo in enumerate(photos):
            photo_url = photo.get_attribute('src')
            img_data = requests.get(photo_url).content
            img_name = f'{page_nr}_{i}.jpg'
            img_path = os.path.join(photos_dir, img_name)
            with open(img_path, 'wb') as h:
                h.write(img_data)
            print(f'Issaugota {i} nuotrauka')

    time.sleep(randint(1,5))


driver.quit()

# %%
options = Options()
options.add_argument('--incognito')

driver = webdriver.Chrome(options=options)
import time
from random import randint
options = Options()
options.add_argument('--incognito')

driver = webdriver.Chrome(options=options)

for page_nr in range(1,100):

    url = f'https://m.autoplius.lt/skelbimai/zemes-ukio-misko-technika-manipuliatoriai/zemes-ukio-savaeige-technika?model=&qt=&category_id=32&type_id%5B6434%5D=6434&page_nr={page_nr}'

    driver.get(url)

    photos = driver.find_elements(By.CLASS_NAME, 'js-gallery-photo')

    for i, photo in enumerate(photos):
        print(i, photo.get_attribute('not-lazy'))

    photos_dir = 'traktoriai'
    if not os.path.exists(photos_dir):
        os.makedirs(photos_dir)
    for i, photo in enumerate(photos):
            photo_url = photo.get_attribute('src')
            img_data = requests.get(photo_url).content
            img_name = f'{page_nr}_{i}.jpg'
            img_path = os.path.join(photos_dir, img_name)
            with open(img_path, 'wb') as h:
                h.write(img_data)
            print(f'Issaugota {i} nuotrauka')

    time.sleep(randint(1,5))


driver.quit()
